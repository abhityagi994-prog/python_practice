# %%
#Q-1: Rectangle Class

#Write a Rectangle class in Python language, allowing you to build a rectangle with length and width attributes.

#Create a Perimeter() method to calculate the perimeter of the rectangle and a Area() method to calculate 
#the area of the rectangle.
#Create a method display() that display the length, width, perimeter and area of an object created using 
#an instantiation on rectangle class.

#Eg. After making above classes and methods, on executing below code:-
#my_rectangle = Rectangle(3 , 4)
#my_rectangle.display()

#Output:
#The length of rectangle is:  3
#The width of rectangle is:  4
#The perimeter of rectangle is:  14
#The area of rectangle is:  12

class Rectangle:

    def __init__(self,length,width):
        self.length=length
        self.width=width

    def __str__(self):
        return "Rectangle ({} , {})".format(self.length,self.width)

    def perimeter(self):
        per=2*(self.length+self.width)
        return per

    def area(self):
        area_=self.length*self.width
        return area_

    def display(self):
        print("The length of rectangle is: ",self.length)
        print("The width of rectangle is: ",self.width)
        print("The perimeter of rectangle is: ",self.perimeter())
        print("The area of rectangle is: ",self.area())

# %%
obj=Rectangle(3,4)

# %%
print(obj)
# Out:
# Rectangle (3 , 4)

# %%
obj.display()
# Out:
# The length of rectangle is:  3
# The width of rectangle is:  4
# The perimeter of rectangle is:  14
# The area of rectangle is:  12

# %%
#Q-2: Bank Class
#Create a Python class called BankAccount which represents a bank account, having as 
#attributes: accountNumber (numeric type), name (name of the account owner as string type), balance.
#Create a constructor with parameters: accountNumber, name, balance.
#Create a Deposit() method which manages the deposit actions.
#Create a Withdrawal() method which manages withdrawals actions.
#Create an bankFees() method to apply the bank fees with a percentage of 5% of the balance account.
#Create a display() method to display account details. Give the complete code for the BankAccount class.
#Eg. After making above classes and methods, on executing below code:-

#newAccount = BankAccount(2178514584, "Mandy" , 2800)
#newAccount.Withdrawal(700)
#newAccount.Deposit(1000)
#newAccount.display()

#Output:
#Account Number :  2178514584
#Account Name :  Mandy
#Account Balance :  3100 ₹

class BankAccount:

    def __init__(self,account_num,name,balance):
        self.__account_num=account_num
        self.__name=name
        self.__balance=balance
        #print(self.__account_num)

    def deposite(self):
        acc_num=int(input("Please enter your account num: "))
        if acc_num==self.__account_num:
            amount=int(input("Enter the amount you want to deposite: "))
            self.__balance=amount+self.__balance
            print("Amount Added successfully")
            return f"Current balance: {self.__balance}"
        else:
            print("Incorrect account num")

    def withdrawl(self):
        acc_num=int(input("Please enter your account num: "))
        if acc_num==self.__account_num:
            withdrawl_amount=int(input("Enter the amount you want to withdraw! "))
            if withdrawl_amount<=self.__balance:
                self.__balance=self.__balance - withdrawl_amount
                self.bankfees()
                print("Remaining balance", self.__balance)
            else:
                print("Withdrawl Amount exceed the current amount!")
        else:
            print("Incorrect account num")

    def bankfees(self):
        self.__balance=self.__balance - (self.__balance*0.05)
        return self.__balance
        
    def display(self):
        print("Account number: ",self.__account_num)
        print("Account Name: ",self.__name)
        print("Account Balance: ",self.__balance)

# %%
customer=BankAccount(7291,"Liya",5000)
# Out:
# 7291

# %%
customer.deposite()
# Out:
# Please enter your account num:  7291
# Enter the amount you want to deposite:  1000
# Amount Added successfully
# 'Current balance: 6000'

# %%
customer.withdrawl()
# Out:
# Please enter your account num:  7291
# Enter the amount you want to withdraw!  1000
# Remaining balance 4750.0

# %%
#Q-3:Computation class
#Create a Computation class with a default constructor (without parameters) allowing to 
#perform various calculations on integers numbers.

#Create a method called Factorial() which allows to calculate the factorial of an integer n. Integer n as 
#parameter for this method

#Create a method called naturalSum() allowing to calculate the sum of the first n integers 1 + 2 + 3 + .. + n. 
#Integer n as parameter for this method.

#Create a method called testPrime() in the Calculation class to test the primality of a given integer n, 
#n is Prime or Not? Integer n as parameter for this method.

#Create a method called testPrims() allowing to test if two numbers are prime between them. Two integers 
#are prime to one another if they have only 1 as their common divisor. Eg. 4 and 9 are prime to each other.

#Create a tableMult() method which creates and displays the multiplication table of a given integer. 
#Then create an allTablesMult() method to display all the integer multiplication tables 1, 2, 3, ..., 9.

#Create a static listDiv() method that gets all the divisors of a given integer on new list called Ldiv. 
#Create another listDivPrim() method that gets all the prime divisors of a given integer.

import math
class Computation:
    
    def __init__(self):
        pass
        
    def factorial(slef,num):
        product=1
        for i in range(1,num+1):
            product=product*i
        return product

    def naturalSum(self,num):
        total=0
        for i in range(1,num+1):
            total=total+i
        return total

    def testPrime(self,num):
        if num==0 or num==1:
            return False
        elif num==2:
            return True
        elif num%2==0:
            return False
        else:
            for i in range(3,math.floor(math.sqrt(num))+1,2):
                if num%i==0:
                    return False
            else:
                return True

    def tableMult(self,num):
        for i in range(1,11):
            print(f"{num} * {i} = {i*num}")

    def listDiv(self,num):
        Ldiv=[]
        for i in range(1,num+1):
            if num%i==0:
                Ldiv.append(i)
        return Ldiv

    def listDivPrime(self,num):
        LdivPrm=[]
        for i in range(1,num):
            if num%i==0:
                if self.testPrime(i):
                    LdivPrm.append(i)
        return LdivPrm

# %%
obj=Computation()

# %%
obj.factorial(5)
# Out:
# 120

# %%
obj.naturalSum(5)
# Out:
# 15

# %%
print(obj.testPrime(5))
print(obj.testPrime(27))
print(obj.testPrime(31))
# Out:
# True
# False
# True

# %%
obj.tableMult(5)
# Out:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %%
obj.listDiv(20)
# Out:
# [1, 2, 4, 5, 10, 20]

# %%
print(obj.listDivPrime(20))
# Out:
# [2, 5]
# [2, 5]

# %%
#Q-4: Build flashcard using class in Python.
#Build a flashcard using class in python. A flashcard is a card having information on both 
#sides, which can be used as an aid in memoization. Flashcards usually have a question on one side 
#and an answer on the other.

#Example 1:

#Approach:

#Create a class named FlashCard.
#Initialize dictionary fruits using init() method. Here you have to define fruit name as key and 
#it's color as value. E.g., {"Banana": "yellow", "Strawberries": "pink"}
#Now randomly choose a pair from fruits by using random module and store the key in variable fruit 
#and value in variable color.
#Now prompt the user to answer the color of the randomly chosen fruit.
#If correct print correct else print wrong.

import random
class FlashCard:

    def __init__(self):
        self.__dictionary={}
        self.__variable_fruit=""
        self.__adding_ques()


    def __adding_ques(self):
        user_input=int(input("""
        Hi, what would you like to do?
        1. Add the questinons 
        2. Play the quiz game
        3. Exit
        """))

        if user_input==1:
            self.__ques()
        elif user_input==2:
            self.__quiz()
        else:
            exit

    def __ques(self):
        q=int(input("How many question you want to add: "))
        for i in range(0,q):
            k=input("Please enter the fruit name: ")
            v=input("Please enter the colour of fruit")
            self.__dictionary[k]=v
            print("The question is added to the database!")
        self.__adding_ques()
        
    def __quiz(self):
        if len(self.__dictionary)!=0:
            self.__variable_fruit=random.choice(list(self.__dictionary.keys()))
            self.__variable_colour=self.__dictionary[self.__variable_fruit]
            self.__final_quiz()
        else:
            print("Add the questions first please! ")
            self.__adding_ques()

    def __final_quiz(self):
            print("Welcome to fruit quiz!")
            question=input(f"What is the colour of {self.__variable_fruit} ?")
            if question==self.__variable_colour:
                print("Correct Answer! \U0001F604")
            else:
                print("Incorrect Answer! \U0001F608")
            question1=int(input("Enter 0 to play again or 1 to exit"))

            if question1==0:
                self.__quiz()
            elif question1==1:
                exit

# %%
obj=FlashCard()
# Out:
#         Hi, what would you like to do?
#         1. Add the questinons
#         2. Play the quiz game
#         3. Exit
#          1
# How many question you want to add:  1
# Please enter the fruit name:  apple
# Please enter the colour of fruit red
# The question is added to the database!
#         Hi, what would you like to do?
#         1. Add the questinons
#         2. Play the quiz game
#         3. Exit
#          2
# Welcome to fruit quiz!
# What is the colour of apple ? red
# Correct Answer! 😄
# Enter 0 to play again or 1 to exit 1
